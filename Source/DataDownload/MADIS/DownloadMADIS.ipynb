# %% [markdown]
# # Madis Download

# %%
from dateutil import rrule
from datetime import datetime
import multiprocessing
from pathlib import Path
import xarray as xr
import warnings
import pandas as pd
import tqdm
from IPython.display import clear_output

# %%
dataPath = Path('/projects3/home/flag0220/LocalizedWeather/WindDataNE-US')
targetFolder = dataPath / 'madis' / 'raw'
targetFolder.mkdir(parents=True, exist_ok=True)

# %%
mesonetUrl = lambda year, month, day, hour: f'https://madis-data.ncep.noaa.gov/madisPublic1/data/archive/{year}/{month:02d}/{day:02d}/LDAD/mesonet/netCDF/{year}{month:02d}{day:02d}_{hour:02d}00.gz'

# %%
startDate = '2019-01-01'
endDate = '2024-01-01'
dt = rrule.HOURLY

dates = list(rrule.rrule(dt, dtstart=datetime.strptime(startDate, '%Y-%m-%d'),
                      until=datetime.strptime(endDate, '%Y-%m-%d')))[:-1]

# %%
def getDataForDate(date):
    year = date.year
    month = date.month
    day = date.day
    hour = date.hour
    url = mesonetUrl(year, month, day, hour)
    outputFile = targetFolder/f'{year}/{month}/mesonet/{year}{month:02d}{day:02d}_{hour:02d}00.gz'
    if outputFile.exists():
        return
    
    outputFile.parent.mkdir(parents=True, exist_ok=True)
    outputFileStr = outputFile.as_posix()
    
    try:
        # !wget $url -O "$outputFileStr" --no-check-certificate
    except:
        print('ERRRORR')
        print(date)
        print('ERRRORR')
        return

# %%
with multiprocessing.Pool(128) as pool:
    pool.map(getDataForDate, dates)

# %%
# for date in dates:
#     getDataForDate(date)

# %% [markdown]
# # Concatenate MADIS data by Month

# %%
var_list = ['stationId', 'reportTime', 'latitude', 'longitude', 'elevation', 'dewpoint', 'dewpointDD', 'temperature', 'temperatureDD', 'windSpeed', 'windSpeedDD', 'windDir', 'windDirDD', 'relHumidity', 'relHumidityDD', 'dewpoint', 'dewpointDD', 'solarRadiation']

# %%
inputPath = lambda year, month: targetFolder / f'{year}/{month}/mesonet/'

# %%
targetPath = lambda year, month: dataPath.parent/'raw_monthly'/'mesonet'/str(year)

# %%
def processOnOpening(d):
    d = d[var_list]
    data_vars = {}
    for varname in var_list:
        data_vars[varname] = xr.Variable(
            dims=d.data_vars[varname].dims,
            data=d.data_vars[varname],
            encoding={'chunks': d.data_vars[varname].shape})
    data = xr.Dataset(data_vars=data_vars)
    return data

# %%
def processFile(file):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        # xr.open_dataset(datafiles[0])
        data = xr.open_mfdataset(file, preprocess=processOnOpening)  #, coords='all')#, parallel=True)
        data = data.to_pandas().reset_index(drop=True)
        data.insert(0, 'minute', data.reportTime.dt.minute.values)
        data.insert(0, 'hour', data.reportTime.dt.hour.values)
        data.insert(0, 'day', data.reportTime.dt.day.values)
        data.insert(0, 'month', data.reportTime.dt.month.values)
        data.insert(0, 'year', data.reportTime.dt.year.values)
        data = data.drop(columns='reportTime')
    return data

# %%
for year in range(2019, 2024):
    for month in range(1, 13):
        
        outPath = targetPath(year, month)/(f'{month}.nc')
        if outPath.exists():
            continue
        
        datafiles = list(inputPath(year, month).glob('*.gz'))
        out = []
        with multiprocessing.Pool(32) as pool:
            for result in tqdm.tqdm(pool.imap_unordered(processFile, datafiles), total=len(datafiles)):
                out.append(result)
        out = pd.concat(out).to_xarray()
        
        outPath.parent.mkdir(parents=True, exist_ok=True)
        out.to_netcdf(outPath)
    
    clear_output(wait=False)
# Out:
#  84%|████████▍ | 567/672 [00:53<00:09, 10.65it/s]
# Process ForkPoolWorker-340:
# Process ForkPoolWorker-328:
# Process ForkPoolWorker-344:
# Process ForkPoolWorker-347:
# Process ForkPoolWorker-350:
# Process ForkPoolWorker-348:
# Process ForkPoolWorker-330:
# Process ForkPoolWorker-342:
# Process ForkPoolWorker-346:
# Process ForkPoolWorker-322:
# Process ForkPoolWorker-326:
# Process ForkPoolWorker-323:
# Process ForkPoolWorker-343:
# Process ForkPoolWorker-336:
# Process ForkPoolWorker-325:
# Process ForkPoolWorker-331:
# Process ForkPoolWorker-345:
# Process ForkPoolWorker-333:
# Process ForkPoolWorker-321:
# Process ForkPoolWorker-341:
# Process ForkPoolWorker-335:
# Process ForkPoolWorker-349:
# Process ForkPoolWorker-334:
# Process ForkPoolWorker-324:
# Process ForkPoolWorker-352:
# Process ForkPoolWorker-339:
# Process ForkPoolWorker-338:
# Process ForkPoolWorker-337:
# Process ForkPoolWorker-351:
# Process ForkPoolWorker-327:
# Process ForkPoolWorker-329:
# Process ForkPoolWorker-332:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_3127254/505611378.py", line 5, in processFile
#     data = xr.open_mfdataset(file, preprocess=processOnOpening)  #, coords='all')#, parallel=True)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/site-packages/xarray/backends/api.py", line 1635, in open_mfdataset
#     datasets = [open_(p, **open_kwargs) for p in paths1d]
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/site-packages/xarray/backends/api.py", line 1635, in <listcomp>
#     datasets = [open_(p, **open_kwargs) for p in paths1d]
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/site-packages/xarray/backends/api.py", line 668, in open_dataset
#     engine = plugins.guess_engine(filename_or_obj)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/site-packages/xarray/backends/plugins.py", line 194, in guess_engine
#     raise ValueError(error_msg)
# ValueError: did not find a match in any of xarray's currently installed IO backends ['netcdf4', 'h5netcdf', 'scipy']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# https://docs.xarray.dev/en/stable/user-guide/io.html
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 11
#      10 with multiprocessing.Pool(32) as pool:
# ---> 11     for result in tqdm.tqdm(pool.imap_unordered(processFile, datafiles), total=len(datafiles)):
#      12         out.append(result)
#
# File ~/anaconda3/envs/mpnn/lib/python3.10/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#
# File ~/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py:873, in IMapIterator.next(self, timeout)
#     872     return value
# --> 873 raise value
#
# ValueError: did not find a match in any of xarray's currently installed IO backends ['netcdf4', 'h5netcdf', 'scipy']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# https://docs.xarray.dev/en/stable/user-guide/io.html
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 10
#       8 datafiles = list(inputPath(year, month).glob('*.gz'))
#       9 out = []
# ---> 10 with multiprocessing.Pool(32) as pool:
#      11     for result in tqdm.tqdm(pool.imap_unordered(processFile, datafiles), total=len(datafiles)):
#      12         out.append(result)
#
# File ~/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py:739, in Pool.__exit__(self, exc_type, exc_val, exc_tb)
#     738 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 739     self.terminate()
#
# File ~/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py:657, in Pool.terminate(self)
#     655 util.debug('terminating pool')
#     656 self._state = TERMINATE
# --> 657 self._terminate()
#
# File ~/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/util.py:224, in Finalize.__call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     221 else:
#     222     sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223               self._callback, self._args, self._kwargs)
# --> 224     res = self._callback(*self._args, **self._kwargs)
#     225 self._weakref = self._callback = self._args = \
#     226                 self._kwargs = self._key = None
#     227 return res
#
# File ~/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py:703, in Pool._terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     701 result_handler._state = TERMINATE
#     702 change_notifier.put(None)
# --> 703 outqueue.put(None)                  # sentinel
#     705 # We must wait for the worker handler to exit before terminating
#     706 # workers because we don't want workers to be restarted behind our back.
#     707 util.debug('joining worker handler')
#
# File ~/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py:376, in SimpleQueue.put(self, obj)
#     374     self._writer.send_bytes(obj)
#     375 else:
# --> 376     with self._wlock:
#     377         self._writer.send_bytes(obj)
#
# File ~/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py:95, in SemLock.__enter__(self)
#      94 def __enter__(self):
# ---> 95     return self._semlock.__enter__()
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 377, in put
#     self._writer.send_bytes(obj)
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/queues.py", line 376, in put
#     with self._wlock:
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/connection.py", line 405, in _send_bytes
#     self._send(buf)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/flag0220/anaconda3/envs/mpnn/lib/python3.10/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# KeyboardInterrupt
